# %%
import requests
from bs4 import BeautifulSoup
from xml.etree import ElementTree
import pandas as pd
import time
import numpy as np

# %%
# a = soup.find_all("span", {"class": 'lot-size' })
# [el.getText() for el in a]

# %%
def find_attr(sp, *attrs):
    obj = sp
    for attr in attrs:
        if obj.find(attr):
            obj = obj.find(attr)
        else:
            return np.nan
    return obj.getText()

# %%
listings2 = []

# %%
for i in range(1,21):
    #print i
    page_url = "http://www.zillow.com/homes/for_sale/Boston-MA/44269_rid/any_days/42.4379,-70.629044,42.191135,-71.310883_rect/10_zm/%d_p/" % i
    page = requests.get(page_url).text
    page_soup = BeautifulSoup(page, 'html.parser')
    
    item = page_soup.find("div", {"id": 'search-results' }).find_all("article", {"class": "property-listing"})
    if not len(item) == 26:
        print i, len(item)
    else:
        listings2 = listings2 + item
    time.sleep(2)
# Out:
# 4 0
# 7 0
# 8 0
# 18 0
# 19 0

# %%
rec_arr = []
price_arr = []

# %%
zid = 'X1-ZWz1f9f43srdhn_5b1bv'

def request_record(listing):
    
    el = listing.find("figure").find("a")["href"][13:-1].split('/')[0]
    addr_zip = ('+'.join(el.split('-')[:3]) , el.split('-')[-1])  
    
    url = 'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id='+ zid \
            +'&address='+ addr_zip[0] \
            +'&citystatezip=' + addr_zip[1]

    req = requests.get(url)
    
    soup = BeautifulSoup(req.text).find('response')
    
    if soup:         
        record = {}
        record['lat'] = find_attr(soup, 'address', 'latitude') 
        record['lng'] = find_attr(soup, 'address', 'longitude') 
        record['yr'] = find_attr(soup, 'yearbuilt') 
        record['sz'] = find_attr(soup, 'lotsizesqft') 
        record['fsz'] = find_attr(soup, 'finishedsqft') 
        record['rm'] = find_attr(soup, 'totalrooms') 
        record['val'] = find_attr(soup, 'zestimate', 'amount') 
        record['use'] = find_attr(soup, 'usecode') 
        record['url'] = url
        return record
    else:
        return {'lat': "",
                'lng': "",
                'yr': "",
                'sz': "",
                'fsz': "",
                'rm': "",
                'val': "",
                'use': "",
                'url': url
               }
    
def find_price(listing):  
    price = listing.find("dt", {"class": 'price-large' })
    return price.getText() if price else np.nan

# %%
rec_arr2 = map(request_record, listings)
# price_arr = map(find_price, listings)

# %%
df = pd.DataFrame.from_records(rec_arr)
df['price'] = price_arr

# %%
df2 = pd.DataFrame.from_records(rec_arr2)
df2['price'] = price_arr

# %%
df2
# Out:
#       fsz        lat         lng   rm      sz  \
# 0    1288  42.286256  -71.120207  NaN   21969
# 1    2040    42.2483  -71.115951    7    8276
# 2     NaN   42.30703   -71.11543  NaN     NaN
# 3    3132  42.244716  -71.121903   13    7046
# 4    1421  42.380374  -71.033872    7    1750
# 5    1528  42.350753  -71.086331    5    1742
# 6    1147    42.3662   -71.06725  NaN     NaN
# 7    2256   42.38243  -71.033284   10    1742
# 8    1654   42.31189  -71.090065    6    1742
# 9    1168   42.30887  -71.059367    7    2178
# 10   1926  42.333774  -71.036849   11    1045
# 11    399  42.343083  -71.103753    2     399
# 12    598  42.303811  -71.116252  NaN     NaN
# 13    795  42.327227  -71.108202    4     795
# 14   1578  42.344594  -71.064406  NaN     NaN
# 15    NaN   42.34943   -71.13229  NaN     NaN
# 16    760  42.339447  -71.080154  NaN     NaN
# 17   1209   42.27354  -71.147425    6    6534
# 18   3965  42.355358  -71.131156  NaN    2178
# 19   2031  42.287465  -71.063176    9    3049
# 20   1729  42.373195  -71.064762    7    1729
# 21   2076   42.31954  -71.080334   10    3049
# 22    922  42.376068  -71.039183  NaN     NaN
# 23   1819   42.26948   -71.09533   10    6098
# 24   1308   42.35043   -71.05703  NaN     NaN
# 25   1030  42.345577  -71.141085  NaN     NaN
# 26   1151  42.314373  -71.055694  NaN    1151
# 27    815   42.35382   -71.07824    3     673
# 28    900  42.383333  -71.070579    3     435
# 29   1107  42.246778  -71.113791    6    6534
# ..    ...        ...         ...  ...     ...
# 516  1478   42.33244   -71.03223    7     NaN
# 517  1250  42.321731  -71.122276    3  980100
# 518
# 519
# 520   985  42.380699  -71.066268  NaN     NaN
# 521
# 522
# 523  2000  42.337398  -71.034808  NaN     NaN
# 524  1927  42.276878  -71.135446    6    9522
# 525  1679  42.291523  -71.112758    6    5662
# 526
# 527
# 528  1325  42.342102  -71.057312    5    2025
# 529  1035   42.35014   -71.09155  NaN     NaN
# 530  1024   42.32502   -71.11208  NaN     NaN
# 531  2902  42.312617  -71.109716   13    7279
# 532
# 533
# 534
# 535  3351  42.342916  -71.087013    9    1742
# 536
# 537  1136   42.33061  -71.047099    4    1136
# 538
# 539  3714  42.281973  -71.089434   15    3150
# 540
# 541  1674    42.3665  -71.032769   10    1012
# 542
# 543
# 544  1478   42.33244   -71.03223    7     NaN
# 545  2494  42.291007   -71.05017  NaN    2613
#
#                                                    url               use  \
# 0    http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 1    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 2    http://www.zillow.com/webservice/GetDeepSearch...         Apartment
# 3    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 4    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 5    http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 6    http://www.zillow.com/webservice/GetDeepSearch...  MultiFamily5Plus
# 7    http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 8    http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 9    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 10   http://www.zillow.com/webservice/GetDeepSearch...            Duplex
# 11   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 12   http://www.zillow.com/webservice/GetDeepSearch...         Townhouse
# 13   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 14   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 15   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 16   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 17   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 18   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 19   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 20   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 21   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 22   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 23   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 24   http://www.zillow.com/webservice/GetDeepSearch...  MultiFamily5Plus
# 25   http://www.zillow.com/webservice/GetDeepSearch...           Unknown
# 26   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 27   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 28   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 29   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# ..                                                 ...               ...
# 516  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 517  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 518  http://www.zillow.com/webservice/GetDeepSearch...
# 519  http://www.zillow.com/webservice/GetDeepSearch...
# 520  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 521  http://www.zillow.com/webservice/GetDeepSearch...
# 522  http://www.zillow.com/webservice/GetDeepSearch...
# 523  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 524  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 525  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 526  http://www.zillow.com/webservice/GetDeepSearch...
# 527  http://www.zillow.com/webservice/GetDeepSearch...
# 528  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 529  http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 530  http://www.zillow.com/webservice/GetDeepSearch...  MultiFamily5Plus
# 531  http://www.zillow.com/webservice/GetDeepSearch...           Triplex
# 532  http://www.zillow.com/webservice/GetDeepSearch...
# 533  http://www.zillow.com/webservice/GetDeepSearch...
# 534  http://www.zillow.com/webservice/GetDeepSearch...
# 535  http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 536  http://www.zillow.com/webservice/GetDeepSearch...
# 537  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 538  http://www.zillow.com/webservice/GetDeepSearch...
# 539  http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 540  http://www.zillow.com/webservice/GetDeepSearch...
# 541  http://www.zillow.com/webservice/GetDeepSearch...            Duplex
# 542  http://www.zillow.com/webservice/GetDeepSearch...
# 543  http://www.zillow.com/webservice/GetDeepSearch...
# 544  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 545  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
#
#          val    yr       price
# 0     360741  2011    $399,000
# 1     629907  2000    $599,000
# 2              NaN    $644,900
# 3     510706  1880    $218,000
# 4     339559  1900    $389,900
# 5    1919821  1875  $2,099,000
# 6             1964    $736,000
# 7     417105  1900    $489,000
# 8     343037  2004    $241,000
# 9     312712  1900    $225,000
# 10    711434  1890         NaN
# 11    342145  1918    $319,900
# 12    423774  1986    $239,900
# 13    343897  1910    $319,900
# 14   1901456   NaN    $729,000
# 15    289873  1920    $425,000
# 16    971530   NaN    $439,900
# 17    409455  1950    $499,900
# 18   1451474  1900  $1,750,000
# 19    354584  1897    $449,999
# 20   1146956  1870    $579,000
# 21    387310  1900    $399,000
# 22    377044  2016    $475,000
# 23    358991  1900    $359,000
# 24            1913    $995,000
# 25    526225  1930    $409,000
# 26    423933  1905    $409,000
# 27    779016  1920    $779,000
# 28    436938  1885    $449,000
# 29    391232  1946    $424,900
# ..       ...   ...         ...
# 516   715413   NaN    $699,000
# 517   744982  1880  $1,100,000
# 518                 $1,100,000
# 519                 $1,650,000
# 520   594314  1992    $639,900
# 521                   $299,000
# 522                 $1,089,000
# 523  1265574  2012  $1,049,000
# 524   481246  1925    $449,900
# 525   556306  1940    $649,000
# 526                   $929,000
# 527                 $1,295,000
# 528  1951753  2007  $1,300,000
# 529   805218   NaN    $589,000
# 530            NaN    $314,500
# 531  1070312  1890    $659,000
# 532                   $449,000
# 533                   $624,617
# 534                   $699,000
# 535  1223944  1886  $2,395,000
# 536                 $1,250,000
# 537   508977  2000    $624,617
# 538                   $449,900
# 539   538712  1900    $649,900
# 540                   $579,000
# 541   475738  1899    $535,000
# 542                   $579,000
# 543                   $539,000
# 544   715413   NaN    $699,000
# 545   564955   NaN    $499,900
#
# [546 rows x 10 columns]

# %%
df
# Out:
#       fsz        lat         lng   rm      sz  \
# 0    1288  42.286256  -71.120207  NaN   21969
# 1    2040    42.2483  -71.115951    7    8276
# 2     NaN   42.30703   -71.11543  NaN     NaN
# 3    3132  42.244716  -71.121903   13    7046
# 4    1421  42.380374  -71.033872    7    1750
# 5    1528  42.350753  -71.086331    5    1742
# 6    1147    42.3662   -71.06725  NaN     NaN
# 7    2256   42.38243  -71.033284   10    1742
# 8    1654   42.31189  -71.090065    6    1742
# 9    1168   42.30887  -71.059367    7    2178
# 10   1926  42.333774  -71.036849   11    1045
# 11    399  42.343083  -71.103753    2     399
# 12    598  42.303811  -71.116252  NaN     NaN
# 13    600  42.327227  -71.108202    3     600
# 14   1578  42.344594  -71.064406  NaN     NaN
# 15    NaN   42.34943   -71.13229  NaN     NaN
# 16    760  42.339447  -71.080154  NaN     NaN
# 17   1209   42.27354  -71.147425    6    6534
# 18   3965  42.355358  -71.131156  NaN    2178
# 19   2031  42.287465  -71.063176    9    3049
# 20   1729  42.373195  -71.064762    7    1729
# 21   2076   42.31954  -71.080334   10    3049
# 22    922  42.376068  -71.039183  NaN     NaN
# 23   1819   42.26948   -71.09533   10    6098
# 24   1308   42.35043   -71.05703  NaN     NaN
# 25   1030  42.345577  -71.141085  NaN     NaN
# 26   1151  42.314373  -71.055694  NaN    1151
# 27    815   42.35382   -71.07824    3     673
# 28    900  42.383333  -71.070579    3     435
# 29   1107  42.246778  -71.113791    6    6534
# ..    ...        ...         ...  ...     ...
# 516  1478   42.33244   -71.03223    7     NaN
# 517  1250  42.321731  -71.122276    3  980100
# 518  1912  42.379371  -71.063395   10    2613
# 519  1633   42.35822   -71.05048  NaN     NaN
# 520   985  42.380699  -71.066268  NaN     NaN
# 521  1055   42.26757   -71.15037  NaN     NaN
# 522  1747  42.348757  -71.062971  NaN   37865
# 523  2000  42.337398  -71.034808  NaN     NaN
# 524  1927  42.276878  -71.135446    6    9522
# 525  1679  42.291523  -71.112758    6    5662
# 526  1248   42.32132  -71.107855    8    2178
# 527  1755  42.342015  -71.078663    6    1755
# 528  1325  42.342102  -71.057312    5    2025
# 529  1035   42.35014   -71.09155  NaN     NaN
# 530  1024   42.32502   -71.11208  NaN     NaN
# 531  2902  42.312617  -71.109716   13    7279
# 532   898    42.3003  -71.108936    6     898
# 533  2946  42.332789  -71.033048   13    2100
# 534  1367  42.322555  -71.115127  NaN     NaN
# 535  3351  42.342916  -71.087013    9    1742
# 536  3468  42.359834  -71.128526   15    4017
# 537  1136   42.33061  -71.047099    4    1136
# 538  1235  42.263482  -71.150457    6    6534
# 539  3714  42.281973  -71.089434   15    3150
# 540  1750  42.286435  -71.117549  NaN    5000
# 541  1674    42.3665  -71.032769   10    1012
# 542  1444  42.277881  -71.142996    7    3921
# 543  1295  42.292602  -71.114381    6    4791
# 544  1478   42.33244   -71.03223    7     NaN
# 545  2494  42.291007   -71.05017  NaN    2613
#
#                                                    url               use  \
# 0    http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 1    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 2    http://www.zillow.com/webservice/GetDeepSearch...         Apartment
# 3    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 4    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 5    http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 6    http://www.zillow.com/webservice/GetDeepSearch...  MultiFamily5Plus
# 7    http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 8    http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 9    http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 10   http://www.zillow.com/webservice/GetDeepSearch...            Duplex
# 11   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 12   http://www.zillow.com/webservice/GetDeepSearch...         Townhouse
# 13   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 14   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 15   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 16   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 17   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 18   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 19   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 20   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 21   http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 22   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 23   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 24   http://www.zillow.com/webservice/GetDeepSearch...  MultiFamily5Plus
# 25   http://www.zillow.com/webservice/GetDeepSearch...           Unknown
# 26   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 27   http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 28   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 29   http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# ..                                                 ...               ...
# 516  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 517  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 518  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 519  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 520  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 521  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 522  http://www.zillow.com/webservice/GetDeepSearch...         Apartment
# 523  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 524  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 525  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 526  http://www.zillow.com/webservice/GetDeepSearch...     Miscellaneous
# 527  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 528  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 529  http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 530  http://www.zillow.com/webservice/GetDeepSearch...  MultiFamily5Plus
# 531  http://www.zillow.com/webservice/GetDeepSearch...           Triplex
# 532  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 533  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 534  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 535  http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 536  http://www.zillow.com/webservice/GetDeepSearch...  MultiFamily5Plus
# 537  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 538  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 539  http://www.zillow.com/webservice/GetDeepSearch...   MultiFamily2To4
# 540  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 541  http://www.zillow.com/webservice/GetDeepSearch...            Duplex
# 542  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 543  http://www.zillow.com/webservice/GetDeepSearch...      SingleFamily
# 544  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
# 545  http://www.zillow.com/webservice/GetDeepSearch...       Condominium
#
#          val    yr       price
# 0     360741  2011    $399,000
# 1     629907  2000    $599,000
# 2              NaN    $644,900
# 3     510706  1880    $218,000
# 4     339559  1900    $389,900
# 5    1919821  1875  $2,099,000
# 6             1964    $736,000
# 7     417105  1900    $489,000
# 8     343037  2004    $241,000
# 9     312712  1900    $225,000
# 10    711434  1890         NaN
# 11    342145  1918    $319,900
# 12    423774  1986    $239,900
# 13    299462  1910    $319,900
# 14   1901456   NaN    $729,000
# 15    289873  1920    $425,000
# 16    971530   NaN    $439,900
# 17    409455  1950    $499,900
# 18   1451474  1900  $1,750,000
# 19    354584  1897    $449,999
# 20   1146956  1870    $579,000
# 21    387310  1900    $399,000
# 22    377044  2016    $475,000
# 23    358991  1900    $359,000
# 24            1913    $995,000
# 25    526225  1930    $409,000
# 26    423933  1905    $409,000
# 27    779016  1920    $779,000
# 28    436938  1885    $449,000
# 29    391232  1946    $424,900
# ..       ...   ...         ...
# 516   715413   NaN    $699,000
# 517   744982  1880  $1,100,000
# 518  1647283  2010  $1,100,000
# 519           1972  $1,650,000
# 520   594314  1992    $639,900
# 521   292897  1986    $299,000
# 522           2002  $1,089,000
# 523  1265574  2012  $1,049,000
# 524   481246  1925    $449,900
# 525   556306  1940    $649,000
# 526   519694  1890    $929,000
# 527  1743399  1875  $1,295,000
# 528  1951753  2007  $1,300,000
# 529   805218   NaN    $589,000
# 530            NaN    $314,500
# 531  1070312  1890    $659,000
# 532   318674  1946    $449,000
# 533  1235578  1890    $624,617
# 534   621356  2004    $699,000
# 535  1223944  1886  $2,395,000
# 536   829823  1915  $1,250,000
# 537   508977  2000    $624,617
# 538   403232  1960    $449,900
# 539   538712  1900    $649,900
# 540   534785  2016    $579,000
# 541   475738  1899    $535,000
# 542   574246  1928    $579,000
# 543   493386  1950    $539,000
# 544   715413   NaN    $699,000
# 545   564955   NaN    $499,900
#
# [546 rows x 10 columns]

# %%
df3 = df.fillna(df2)
len(df3.dropna(subset=['val','price'], how='all'))
# Out:
# 546

# %%
len(df3.drop_duplicates(subset=['url']))
# Out:
# 429

# %%
df3.drop_duplicates(subset=['url']).to_csv('realestate2.csv')

# %% [markdown]
# ## below are trials

# %%
item[0].find("figure").find("a")["href"]
# Out:
# u'/homedetails/306-Bunker-Hill-St-UNIT-1-Boston-MA-02129/59098035_zpid/'

# %%
len(listings)
# Out:
# 520

# %%
page_url = "hhttp://www.zillow.com/homes/for_sale/Boston-MA/44269_rid/any_days/globalrelevanceex_sort/%d_p/" % 1
page = requests.get(page_url).text
page_soup = BeautifulSoup(page, 'html.parser')
# Out:
# 'hhttp://www.zillow.com/homes/for_sale/Boston-MA/44269_rid/any_days/globalrelevanceex_sort/1_p/'

# %%
a = page_soup.find_all("a", {"class": 'hdp-link routable' })
items = [el['href'][13:-1].split('/') for el in a]
addr_zips = [('+'.join(el[0].split('-')[:3]) , el[0].split('-')[-1]) for el in items]

# %%
dt = page_soup.find_all("dt", {"class": 'price-large' })
prices = [el.getText() for el in a]
# Out:
# [u'$599,000',
#  u'$399,000',
#  u'$649,900',
#  u'$241,000',
#  u'$489,000',
#  u'$389,900',
#  u'$225,000',
#  u'$319,900',
#  u'$499,900',
#  u'$424,900',
#  u'$615,000',
#  u'$736,000',
#  u'$699,900',
#  u'$425,000',
#  u'$675,000',
#  u'$875,000',
#  u'$539,000',
#  u'$469,000',
#  u'$539,500',
#  u'$549,000',
#  u'$375,500',
#  u'$729,000',
#  u'$319,900',
#  u'$1,750,000',
#  u'$3,950,000',
#  u'$650,000']

# %%
assert len(addr_zips) == len(prices)
# Out:
# [{'fsz': u'2040',
#   'lat': u'42.2483',
#   'lng': u'-71.115951',
#   'rm': u'7',
#   'sz': u'8276',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=124+Summit+St&citystatezip=02136',
#   'use': u'SingleFamily',
#   'val': u'629907',
#   'yr': u'2000'},
#  {'fsz': u'1288',
#   'lat': u'42.286256',
#   'lng': u'-71.120207',
#   'rm': nan,
#   'sz': u'21969',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=224+Florence+St&citystatezip=02131',
#   'use': u'Condominium',
#   'val': u'360741',
#   'yr': u'2011'},
#  {'fsz': nan,
#   'lat': u'42.30703',
#   'lng': u'-71.11543',
#   'rm': nan,
#   'sz': nan,
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=77+South+St&citystatezip=02130',
#   'use': u'Apartment',
#   'val': u'',
#   'yr': nan},
#  {'fsz': u'1654',
#   'lat': u'42.31189',
#   'lng': u'-71.090065',
#   'rm': u'6',
#   'sz': u'1742',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=123+Ruthven+St&citystatezip=02121',
#   'use': u'Condominium',
#   'val': u'343037',
#   'yr': u'2004'},
#  {'fsz': u'2256',
#   'lat': u'42.38243',
#   'lng': u'-71.033284',
#   'rm': u'10',
#   'sz': u'1742',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=2+Putnam+St&citystatezip=02128',
#   'use': u'MultiFamily2To4',
#   'val': u'417105',
#   'yr': u'1900'},
#  {'fsz': u'1421',
#   'lat': u'42.380374',
#   'lng': u'-71.033872',
#   'rm': u'7',
#   'sz': u'1750',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=87+White+St&citystatezip=02128',
#   'use': u'SingleFamily',
#   'val': u'339559',
#   'yr': u'1900'},
#  {'fsz': u'1168',
#   'lat': u'42.30887',
#   'lng': u'-71.059367',
#   'rm': u'7',
#   'sz': u'2178',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=265+Hancock+St&citystatezip=02125',
#   'use': u'SingleFamily',
#   'val': u'312712',
#   'yr': u'1900'},
#  {'fsz': u'399',
#   'lat': u'42.343083',
#   'lng': u'-71.103753',
#   'rm': u'2',
#   'sz': u'399',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=116+Riverway+APT&citystatezip=02215',
#   'use': u'Condominium',
#   'val': u'342145',
#   'yr': u'1918'},
#  {'fsz': u'1209',
#   'lat': u'42.27354',
#   'lng': u'-71.147425',
#   'rm': u'6',
#   'sz': u'6534',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=49+Partridge+St&citystatezip=02132',
#   'use': u'SingleFamily',
#   'val': u'409455',
#   'yr': u'1950'},
#  {'fsz': u'1107',
#   'lat': u'42.246778',
#   'lng': u'-71.113791',
#   'rm': u'6',
#   'sz': u'6534',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=69+Prospect+St&citystatezip=02136',
#   'use': u'SingleFamily',
#   'val': u'391232',
#   'yr': u'1946'},
#  {'fsz': u'735',
#   'lat': u'42.35485',
#   'lng': u'-71.06344',
#   'rm': u'3',
#   'sz': u'735',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=151+Tremont+St&citystatezip=02111',
#   'use': u'MultiFamily5Plus',
#   'val': u'',
#   'yr': u'1968'},
#  {'fsz': u'1147',
#   'lat': u'42.3662',
#   'lng': u'-71.06725',
#   'rm': nan,
#   'sz': nan,
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=8+Whittier+Pl&citystatezip=02114',
#   'use': u'MultiFamily5Plus',
#   'val': u'',
#   'yr': u'1964'},
#  {'fsz': u'1920',
#   'lat': u'42.277256',
#   'lng': u'-71.145725',
#   'rm': u'6',
#   'sz': u'5227',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=40+Robin+St&citystatezip=02132',
#   'use': u'SingleFamily',
#   'val': u'651892',
#   'yr': u'1920'},
#  {'fsz': nan,
#   'lat': u'42.34943',
#   'lng': u'-71.13229',
#   'rm': nan,
#   'sz': nan,
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=1258+Commonwealth+Ave&citystatezip=02134',
#   'use': u'MultiFamily2To4',
#   'val': u'289873',
#   'yr': u'1920'},
#  {'fsz': u'1792',
#   'lat': u'42.278725',
#   'lng': u'-71.153295',
#   'rm': u'7',
#   'sz': u'6098',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=34+Linnet+St&citystatezip=02132',
#   'use': u'SingleFamily',
#   'val': u'687007',
#   'yr': u'1937'},
#  {'fsz': u'1141',
#   'lat': u'42.367382',
#   'lng': u'-71.053163',
#   'rm': u'5',
#   'sz': u'1141',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=440+Commercial+St&citystatezip=02109',
#   'use': u'Condominium',
#   'val': u'896346',
#   'yr': u'1920'},
#  {'fsz': u'1050',
#   'lat': u'42.311545',
#   'lng': u'-71.060654',
#   'rm': u'5',
#   'sz': u'4214',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=23+Downer+Ave&citystatezip=02125',
#   'use': u'Condominium',
#   'val': u'518411',
#   'yr': u'2016'},
#  {'fsz': u'1872',
#   'lat': u'42.271004',
#   'lng': u'-71.089742',
#   'rm': u'11',
#   'sz': u'6098',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=16+Mamelon+Cir&citystatezip=02126',
#   'use': u'MultiFamily2To4',
#   'val': u'343092',
#   'yr': u'1950'},
#  {'fsz': u'791',
#   'lat': u'42.339385',
#   'lng': u'-71.081382',
#   'rm': u'3',
#   'sz': u'791',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=257+Northampton+St&citystatezip=02118',
#   'use': u'Condominium',
#   'val': u'608799',
#   'yr': u'2011'},
#  {'fsz': u'1599',
#   'lat': u'42.34798',
#   'lng': u'-71.07868',
#   'rm': nan,
#   'sz': nan,
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=1+Huntington+Ave&citystatezip=02116',
#   'use': u'MultiFamily2To4',
#   'val': u'2627717',
#   'yr': u'1999'},
#  {'fsz': u'1365',
#   'lat': u'42.271849',
#   'lng': u'-71.111738',
#   'rm': u'6',
#   'sz': u'11325',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=109+Annafran+St&citystatezip=02131',
#   'use': u'SingleFamily',
#   'val': u'347815',
#   'yr': u'1945'},
#  {'fsz': u'1578',
#   'lat': u'42.344594',
#   'lng': u'-71.064406',
#   'rm': nan,
#   'sz': nan,
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=40+Traveler+St&citystatezip=02118',
#   'use': u'Condominium',
#   'val': u'1901456',
#   'yr': nan},
#  {'fsz': u'795',
#   'lat': u'42.327227',
#   'lng': u'-71.108202',
#   'rm': u'4',
#   'sz': u'795',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=240+Heath+St&citystatezip=02130',
#   'use': u'Condominium',
#   'val': u'343897',
#   'yr': u'1910'},
#  {'fsz': u'3965',
#   'lat': u'42.355358',
#   'lng': u'-71.131156',
#   'rm': nan,
#   'sz': u'2178',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=15A+Linden+St&citystatezip=02134',
#   'use': u'MultiFamily2To4',
#   'val': u'1451474',
#   'yr': u'1900'},
#  {'fsz': u'3435',
#   'lat': u'42.35536',
#   'lng': u'-71.05766',
#   'rm': nan,
#   'sz': u'30149',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=1+Franklin+St&citystatezip=02110',
#   'use': u'Condominium',
#   'val': u'4028681',
#   'yr': u'2016'},
#  {'fsz': u'705',
#   'lat': u'42.36215',
#   'lng': u'-71.052544',
#   'rm': u'4',
#   'sz': u'705',
#   'url': u'http://www.zillow.com/webservice/GetDeepSearchResults.htm?zws-id=X1-ZWz1f9f43srdhn_5b1bv&address=142+Commercial+St&citystatezip=02109',
#   'use': u'Condominium',
#   'val': u'588419',
#   'yr': u'1856'}]

# %%
rec_arr = []
for el in addr_zips:
    rec_arr = rec_arr + [request_record(el)]
    #time.sleep(1000)
prices_all = prices_all + prices
rec_arr_all = rec_arr_all + rec_arr

# %%
df = pd.DataFrame.from_records(rec_arr_all)
df['price'] = prices_all
